# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('grid_search_results.csv')
df.head()
# Out:
#    Data_size  Hidden  Learning Rate  Validation RMSE
# 0      10000      16          0.001         0.001538
# 1      10000      32          0.001         0.003191
# 2      10000      64          0.001         0.002415
# 3      10000     128          0.001         0.002142
# 4      20000      16          0.001         0.001702

# %%
df_sort = df.sort_values(by='Validation RMSE', ascending=False)
df_sort
# Out:
#      Data_size  Hidden  Learning Rate  Validation RMSE
# 193      40000      32          0.010         0.049481
# 163      10000     128          0.009         0.037178
# 199      50000     128          0.010         0.033106
# 181      10000      32          0.010         0.030228
# 170      30000      64          0.009         0.029843
# ..         ...     ...            ...              ...
# 4        20000      16          0.001         0.001702
# 6        20000      64          0.001         0.001694
# 17       50000      32          0.001         0.001595
# 0        10000      16          0.001         0.001538
# 14       40000      64          0.001         0.001217
#
# [200 rows x 4 columns]
