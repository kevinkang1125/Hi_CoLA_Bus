# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
kl_div = np.loadtxt("./Results/KL_Trend_Check_EXP/kl_diver.txt")
Thomas_lb = np.loadtxt("./Results/KL_Trend_Check_EXP/Thomas_cl.txt")
Mean = np.loadtxt("./Results/KL_Trend_Check_EXP/GT.txt")
GT = np.loadtxt("./Results/KL_Trend_Check_EXP/GT_lower_bound_list.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 kl_div = np.loadtxt(".//Results/KL_Trend_Check_EXP/kl_diver.txt")
#       2 Thomas_lb = np.loadtxt("./Results/KL_Trend_Check_EXP/Thomas_cl.txt")
#       3 Mean = np.loadtxt("./Results/KL_Trend_Check_EXP/GT.txt")
#
# File ~/anaconda3/envs/Multiagent_Search/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# File ~/anaconda3/envs/Multiagent_Search/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1012, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1010     fname = os.fspath(fname)
#    1011 if isinstance(fname, str):
# -> 1012     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1013     if encoding is None:
#    1014         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/anaconda3/envs/Multiagent_Search/lib/python3.11/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)
#     188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/anaconda3/envs/Multiagent_Search/lib/python3.11/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: .//Results/KL_Trend_Check_EXP/kl_diver.txt not found.

# %%
d = {"kl_div":kl_div, "Thomas_lb":Thomas_lb, "Population Mean":Mean, "Ground Truth 90 lowerbound":GT}
# data = np.array([kl_div_eb, kl_div_be, Thomas_lb, BS_lb, GT])
df = pd.DataFrame(data=d)
df.sort_values(by="kl_div", ascending=True, inplace=True)

# %%
df["Thomas_error"] = abs(df["Thomas_lb"] - df["Ground Truth 90 lowerbound"])

# %%
df.to_csv("Test/results.csv", index=False)

# %%
# Assign prettier colors based on KL divergence
def assign_color(kl_val):
    if kl_val < 0.2:
        return "#377eb8"  # Red
    elif kl_val <= 1.5:
        return "#4daf4a"  # Green
    else:
        return "#e41a1c"  # Blue

df["color"] = df["kl_div"].apply(assign_color)

# Scatter plot function with 45-degree line
def plot_scatter(ax, x, y, color, xlabel, ylabel, title):
    ax.scatter(x, y, c=color, edgecolors='k', alpha=0.6)
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),
        np.max([ax.get_xlim(), ax.get_ylim()]),
    ]
    ax.plot(lims, lims, 'k--', alpha=0.75, zorder=0)  # 45-degree line
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

plot_scatter(axs[0], df["Thomas_lb"], df["Population Mean"], df["color"], "Thomas", "Population Mean", "Thomas vs Population Mean")
plot_scatter(axs[1], df["Thomas_lb"], df["Ground Truth 90 lowerbound"], df["color"], "Thomas", "Ground Truth 90 lowerbound", "Thomas vs Ground Truth 90 lowerbound")

plt.tight_layout()
plt.show()

# %%
df
# Out:
#       kl_div  Thomas_lb  Population Mean  Ground Truth 90 lowerbound  \
# 6   0.161553   0.400650         0.412776                    0.412616
# 57  0.178453   0.412911         0.420862                    0.420703
# 44  0.186154   0.397474         0.407974                    0.407815
# 63  0.205495   0.378846         0.403087                    0.402929
# 62  0.209354   0.398535         0.407740                    0.407578
# ..       ...        ...              ...                         ...
# 53       inf   0.204873         0.426970                    0.426807
# 59       inf   0.348373         0.419593                    0.419433
# 72       inf   0.256118         0.393495                    0.393340
# 85       inf   0.268228         0.421020                    0.420857
# 97       inf   0.225060         0.420375                    0.420215
#
#     Thomas_error    color
# 6       0.011966  #377eb8
# 57      0.007792  #377eb8
# 44      0.010341  #377eb8
# 63      0.024083  #4daf4a
# 62      0.009043  #4daf4a
# ..           ...      ...
# 53      0.221934  #e41a1c
# 59      0.071060  #e41a1c
# 72      0.137222  #e41a1c
# 85      0.152629  #e41a1c
# 97      0.195155  #e41a1c
#
# [100 rows x 6 columns]
