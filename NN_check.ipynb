# %%
import torch
state_dict = torch.load("Optimized_Behavioural_model.pth")
for key, value in state_dict.items():
    print(f"{key}: {value.shape}")
    print(value)
    print()
# Out:
# model.0.weight: torch.Size([32, 5])
# tensor([[ 0.2118, -0.1278,  0.0753,  0.2123, -0.0922],
#         [-0.4302,  0.2032,  0.0585,  0.4104,  0.4054],
#         [ 0.2965,  0.0468, -0.0420, -0.1755, -0.0681],
#         [-0.0286, -0.3383,  0.4432,  1.0044, -0.8163],
#         [-0.1561,  0.0864, -0.0529,  0.1497,  0.3098],
#         [-0.1434,  0.1573,  0.0759, -0.2323, -0.6137],
#         [-0.1569,  0.0030, -0.0531,  0.3604, -0.0158],
#         [-0.0276, -0.2686, -0.0382,  0.6955,  0.3493],
#         [ 0.1257, -0.3565,  0.3183,  0.0165,  0.0164],
#         [-0.1495, -0.1756,  0.1844, -0.3636, -0.0569],
#         [ 0.0865, -0.7644, -0.8045, -0.0674,  0.1053],
#         [-0.0502,  0.8301, -1.1438, -0.3816, -0.2397],
#         [ 0.1269, -0.0176,  0.1123, -0.6676,  0.3339],
#         [ 0.3252, -0.1488,  0.1480,  0.3789, -0.0079],
#         [ 0.0907,  0.1935, -0.0505, -0.5226, -0.1361],
#         [ 0.1930,  0.2463, -0.1056, -0.5306, -0.2071],
# ...
